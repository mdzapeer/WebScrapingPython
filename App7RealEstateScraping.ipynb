# %%
import requests
from bs4 import BeautifulSoup

# %%
r=requests.get('https://ajman.dubizzle.com/search/?keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1')
c=r.content

# %%
soup=BeautifulSoup(c,"html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" xmlns:fb="https://www.facebook.com/2008/fbml">
#  <head>
#   <script type="text/javascript">
#    var yieldlove_site_id = "dubizzle.com_d_listing_main";
#   </script>
#   <script src="//cdn-a.yieldlove.com/yieldlove-bidder.js?dubizzle.com_d_listing_main" type="text/javascript">
#   </script>
#   <base href=""/>
#   <script src="//cdn.optimizely.com/js/174286067.js">
#   </script>
#   <link href="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/images/favicon-hd.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/" rel="dns-prefetch"/>
#   <link href="//cdn.optimizely.com/" rel="dns-prefetch"/>
#   <link href="//stats.g.doubleclick.net/" rel="dns-prefetch"/>
#   <link href="//platform.twitter.com/" rel="dns-prefetch"/>
#   <link href="//www.google-analytics.com/" rel="dns-prefetch"/>
#   <link href="//connect.facebook.net/en_US/all.js" rel="dns-prefetch"/>
#   <link href="//www.googletagservices.com/" rel="dns-prefetch"/>
#   <link href="//rtax.criteo.com/" rel="dns-prefetch"/>
#   <meta content="index, follow" name="robots">
#    <meta name="user_metadata_hash" value="">
#     <link href="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/images/elements/dubizzle-screenshot.png" rel="image_src"/>
#     <link href="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/images/favicons/dubizzle_114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#     <link href="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/images/favicons/dubizzle_72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#     <link href="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/images/favicons/dubizzle_57x57.png" rel="apple-touch-icon"/>
#     <meta content="63733298548" property="fb:page_id"/>
#     <meta content="Dubizzle.com" name="application-name"/>
#     <meta content="name=Dubizzle Home;action-uri=//ajman.dubizzle.com/;icon-uri=https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/images/favicon-hd.ico" name="msapplication-task"/>
#     <meta content="name=Place an Ad;action-uri=/place-an-ad/pick-a-category/;icon-uri=https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/images/favicon-hd.ico" name="msapplication-task"/>
#     <meta content="name=Change Country;action-uri=//ajman.dubizzle.com/change-location/;icon-uri=https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/images/favicon-hd.ico" name="msapplication-task"/>
#     <meta content="name=Dubizzle on Twitter;action-uri=//twitter.com/dubizzle;icon-uri=//twitter.com/favicon.ico" name="msapplication-task"/>
#     <meta content="name=Dubizzle on Facebook;action-uri=//www.facebook.com/dubizzle;icon-uri=https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/images/icons/facebook-favicon2.ico" name="msapplication-task"/>
#     <title>
#      dubizzle.com
#     </title>
#     <link href="android-app://com.dubizzle.horizontal/dubizzle/categories?country=4&amp;cat_id=" rel="alternate"/>
#     <link charset="utf-8" href="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/css/en/base.css" rel="stylesheet" type="text/css">
#      <link charset="utf-8" href="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/css/en/legacy.css" rel="stylesheet" type="text/css">
#       <link charset="utf-8" href="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/css/en/main.css" rel="stylesheet" type="text/css">
#        <link charset="utf-8" href="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/css/reports.css" rel="stylesheet" type="text/css">
#         <link charset="utf-8" href="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/css/car-report.css" rel="stylesheet" type="text/css"/>
#         <link charset="utf-8" href="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/css/insurance.css" rel="stylesheet" type="text/css"/>
#         <link charset="utf-8" href="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/css/vertical_homepages.css" rel="stylesheet" type="text/css"/>
#         <link charset="utf-8" href="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/css/chat/chat_en.css" rel="stylesheet" type="text/css"/>
#         <link charset="utf-8" href="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/css/print.css" rel="stylesheet" type="text/css"/>
#         <!--[if gt IE 7]><link rel="stylesheet" href="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/css/en/browser/msie/ie8.css" type="text/css" charset="utf-8" /><![endif]-->
#         <!--[if IE 7]><link rel="stylesheet" href="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/css/en/browser/msie/ie7.css" type="text/css" charset="utf-8" /><![endif]-->
#         <!--[if lt IE 7]><link rel="stylesheet" href="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/css/en/browser/msie/ie6.css" type="text/css" charset="utf-8" /><![endif]-->
#         <script charset="utf-8" type="text/javascript">
#          //<![CDATA[
#             var JS_TOOLS = [];
#             //]]>
#         </script>
#         <script charset="utf-8" type="text/javascript">
#          //<![CDATA[
#     var IE6BROWSER;
# 	var START = (new Date).getTime();
# 	var MEDIA_URL = "https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/";
# 	var DEBUG = false;
# 	var GOOGLE_API_KEY = "AIzaSyClGM1SnPNontmiwQHz_vkByycqXKNlH4k";
#     var MAP_LISTINGS_PAGE = false;
#     var DETAIL_PAGE = false
#     var LISTINGS_PAGE = false
#     var PAA_PREVIEW_PAGE = false
#     var GOOGLE_ASYNC_ADS = false;
# 	var SITE_ID = 14;
# 	var SITE_IS_MAPPABLE = false;
# 	var IS_AUTHENTICATED = 'False';
# 	var DBZGLOBAL_CB_CHAIN = [];
# 	var LANGUAGE_CODE = "en";
#         var BASE_DOMAIN = ".dubizzle.com";
# 	var dbzglobal_attach_cb = function (cb){
# 		DBZGLOBAL_CB_CHAIN.push(cb);
# 	};
# 	var EVENTS_INITIALIZED = false;
#     var CV_TIMEOUT = 5000;
#
#
#
#     var dbzglobal_event_adapter = function(el, waiting_for_library){
# 	    waiting_for_library = waiting_for_library || false;
# 		if (!EVENTS_INITIALIZED){
# 			if(document.getElementById('event-lib-loading') === null){
# 				var body = document.getElementsByTagName('body')[0],
# 				p = findPosition(el),
# 				_x = p[0] + el.parentNode.offsetWidth/2,
# 				_y = p[1] - el.parentNode.offsetHeight/2,
# 				loading_div = document.createElement('div');
# 				loading_div.id = "event-lib-loading";
# 				loading_div.style.top = _y + 'px';
# 				loading_div.style.left = _x + 'px';
# 				body.appendChild(loading_div);
# 			}
# 			dbzglobal_attach_cb(function(){ DbzGlobal.eventAdapter(el); loading_div.style.display = 'None'; })
# 		}
# 		return false;
# 	}
#
#     var PHOTO_UPLOAD_OPTIONS = {
#     	max_photos: 10, // max number of photos
#     	max_size: 4 // max size per photo in mb
#     }
# //]]>
#         </script>
#         <script charset="utf-8" type="text/javascript">
#          //<![CDATA[
#
# 	// on load fixes:
# 	function fix_search_tabs_menu() {
# 		if(typeof window['jQuery'] != 'function') {
# 			return setTimeout(fix_search_tabs_menu,300); // wait for jquery
# 		}
# 		$("#menu-tabs option#tab-")[0].selected = true;
# 	}
#     function wait_for_dbzglobal() {
#         if(typeof window['DbzGlobal'] != 'object') {
#             return setTimeout(wait_for_dbzglobal,300);
#         }
#
#
#         try{ (function(){ var ratings = [],pricings=[];
# ratings.push('not rated yet');
# ratings.push('Awesome');
# ratings.push('Great');
# ratings.push('Good');
# ratings.push('Ok');
# ratings.push('Blah');
# pricings.push('High end');
# pricings.push('Expensive');
# pricings.push('Moderate');
# pricings.push('Affordable');
# pricings.push('Budget');
# DbzGlobal.setVerbalRating(ratings);
# DbzGlobal.setVerbalPricing(pricings);})();
#
#         }catch(e){}
#
#         try{ DbzGlobal.setGlobal("searchForms",["END"]);
#         }catch(e){}
#         DbzGlobal.initialize_site();
#     }
# 	//     start init-site
# 	var init_site = function () {
#         wait_for_dbzglobal();
#
#         (function(dbz) {
#             var site_domain = 'xiti.com';
#             var hit_page = 'hit.xiti';
#
#                 var xtsd = "https://logs1270";
#                 var xtsite = "509193";
#
#             var site_hit_url = xtsd + '.' + site_domain + '/' + hit_page + '?s=' + xtsite;
#             // Default to adding analytics image beacon to body tag
#             if (typeof hit_append_element == 'undefined') {
#                 var hit_append_element = jQuery('body');
#             }
#
#             var send_hit_beacon = function(beacon_url) {
#                 var hit_beacon = '<img width="1" height="1" src="' + beacon_url + '" />';
#                 hit_append_element.append(hit_beacon);
#             };
#
#             var send_hit_function = function(site_vars, page_vars) {
#                 try {
#                     if (!page_vars) {
#                         page_vars = '';
#                     }
#
#                     var this_url = encodeURIComponent(window.location);
#                     var random_number = Math.floor(Math.random() * Math.pow(10, 10));
#                     var hit_url = site_hit_url;
#                     hit_url += '&p=' + page_vars;
#                     hit_url += '&stc=' + site_vars;
#                     hit_url += '&ref=' + this_url;
#                     hit_url += '&na=' + random_number;
#                     send_hit_beacon(hit_url);
#                 } catch (error) {
#                     console.log('ati: hit tracking failed' + error);
#                 }
#             };
#
#             if (dbz.ATI == undefined) {
#                 dbz.ATI = {};
#             }
#
#             dbz.ATI.send_hit = send_hit_function;
#         })(window.DbzGlobal);
#
#
#
#                 var xtnv = document;
#                 var xtsd = "https://logs1270";
#                 var xtsite = "509193";
#                 var xtcustom = {"city":"ajman","keyword":"Ajman%20Pearl","nb_results":"438","page_name":"listing_list","filters":"keywords:Ajman%20Pearl/is_basic_search_widget:1","error":"0"};
#                 var xt_tags = "[english]";
#                 var xtparam_params = "&tag=" + xt_tags;
#                 var xtergo = "1";
#                 var track_report_item_vars = "";
#
#
#
#                 if (window.xtparam != null) {
#                     window.xtparam += xtparam_params;
#                 }
#                 else {
#                     window.xtparam = xtparam_params;
#                 }
#
#
#
#                         var xtidmod = "2";
#
#
#
#
#
#
#
#
#                    // ATI click events for RP and SP sections on mylistings page for refresh, bulk refresh, delete, bulk delete, manage ad, feature, and edit
#                     dbz.ati_click_processor = function(e, action_type, dataStc) {
#                         if(!!e && !!e.isTrigger){
#                             return;
#                         }
#                         var contextVars = JSON.parse(decodeURIComponent("%7B%22city%22%3A%22ajman%22%2C%22page_name%22%3A%22listing_list%22%2C%22nb_actions%22%3A%221%22%2C%22error%22%3A%220%22%7D"));
#                         contextVars['action_type'] = action_type ? action_type : (
#                             $(this).attr("data-section") ? ($(this).attr("data-ati") + "_" + $(this).attr("data-section")) : $(this).attr("data-ati")
#                         );
#                         var atiVars = encodeURIComponent(JSON.stringify(contextVars));
#                         var stcVars =  $(this).attr("data-stc") ? JSON.parse($(this).attr("data-stc")) :  dataStc;
#                         if(stcVars){
#                             _.each(stcVars, function(stcVar, key){
#                                 !!window.xtcustom && (window.xtcustom[key] = stcVar);
#                             });
#
#                             !!window.xtcustom || console.warn("Couldn't send your ATI event's stc vaiables");
#                             try {
#                                 xt38=(xw && xw.xtcustom!=null)?xtserial(xw.xtcustom):'';
#                             } catch(e) {
#                                 console.log(e);
#                             }
#                         }
#
#                         try {
#                             xt_click(this, 'C', 7, contextVars['action_type'], 'A');
#                         } catch(e) {
#                             console.log(e);
#                         }
#
#                         if ( $(this).attr("data-ati-delay") ) {
#                             e && e.preventDefault();
#                             var href = $(this).attr('href');
#                             setTimeout(function(){
#                                 window.location = href;
#                             }, parseInt($(this).attr("data-ati-delay")));
#                         }
#                         // remone the custom vars from xtcustom
#                         if(dataStc && dataStc.action_type && window.xtcustom && window.xtcustom.action_type) {
#                             delete window.xtcustom.action_type;
#                             xt38 = (xw && xw.xtcustom != null) ? xtserial(xw.xtcustom) : ''
#                         }
#                         return true;
#                     }
#
#                     try {
#                         $(document).on('click',"[data-ati]", dbz.ati_click_processor);
#                     } catch(err){
#                         console.log("Error: ", err);
#                     }
#
#
#
#                 window.ATI_ready = true;
#
#
#
#
#         window.topjsLoaded = true;
#         window.dataLayer = window.dataLayer || [];
#         window.dataLayer.push({"call": "samurai"});
#
#         if ($('body.mini-survey-p').length) {
#             minisurvey_datepicker_init();
#         }
#
#         // Initiailizing _gaq variable incase it's not there when the
#         // page is loaded or if network fails
#         window._gaq = window._gaq || [];
#         window.dbz = window.dbz || {};
#
#         // safe_js: enables us to run any javascript code in guraded
#         // environment, it'll evaluate the first argument which is always a
#         // function and incase of exception print exceptions to console.
#         window.dbz.safe_js = function(fn) {
#             try {
#                 return fn();
#             } catch (err) {
#                 if (console && console.log) {
#                     console.log(err)
#                 }
#             }
#         };
#
#
#
# 	} // end init-site
#
#     function googleSectionalElementInit() {
#         new google.translate.SectionalElement({
#           sectionalNodeClassName: 'trans_toggle_text',
#           controlNodeClassName: 'title',
#           background: '#f4fa58'
#         }, 'gtrans_placeholder');
#     }
#
# //]]>
#         </script>
#         <script charset="utf-8" type="text/javascript">
#          //<![CDATA[
#         </script>
#         <script src="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/js/paa/lib/modernizr.js" type="text/javascript">
#         </script>
#         <script src="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/js/modules/vendors/jquery.js" type="text/javascript">
#         </script>
#         <script src="https://maps.googleapis.com/maps/api/js?key=AIzaSyClGM1SnPNontmiwQHz_vkByycqXKNlH4k">
#         </script>
#         <!-- script src="https://cdn.jsdelivr.net/gmaps/0.4.24/gmaps.min.js"></script -->
#         <script src="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/js/new_map_plugins.js" type="text/javascript">
#         </script>
#         <script charset="utf-8" type="text/javascript">
#          var JS_LIB = [
#
#         'https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/js/jsi18nen0011.js',
#         'https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/js/top.js',
#
#         "//stats.g.doubleclick.net/dc.js",
#         "//platform.twitter.com/widgets.js",
#         "//www.googleadservices.com/pagead/conversion.js"
#         ];
#
#     var tourSource = "";
#     var _360Enabled = (tourSource!== "None") && !!tourSource;
#
#     function init360tour (_360Enabled) {
#         if(!_360Enabled){
#             return;
#         }
#         var bundleUrl = ""
#         var id = "";
#
#         embedpano({
#             id:"krpanoSWFObject"
#             ,xml: bundleUrl + "/" + id + "/" + id + ".xml"
#             ,target:"panoDIV"
#             ,passQueryParameters:true
#             ,bgcolor:"#000000"
#             ,focus: true
#             ,vars:{norotation:true}
#             ,html5:"only"
#         });
#     }
#
#
#     JS_LIB = JS_LIB.concat(JS_TOOLS);
#
#     Modernizr.load([{
#         load: JS_LIB,
#         complete: function(){
#             init_site();
#         }
#     },{
#         load:'//www.googletagservices.com/tag/js/gpt.js'
#     }]);
#
#     $(document).ready(function(){
#         if (!!$("#tourDIV").length){
#             init360tour(_360Enabled);
#         }
#     });
#         </script>
#         <!--[if IE 6]>
# <script type="text/javascript" charset="utf-8">
# //<![CDATA[
# 	try {document.execCommand("BackgroundImageCache", false, true);} catch(err) {}; // fixing background flicker in ie6
# //]]>
# </script>
# <script type="text/javascript" src="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/js/tools/DD_belatedPNG_0.0.7a-min.js"></script>
# <script type="text/javascript" charset="utf-8">//<![CDATA[ DD_belatedPNG.fix("#container"); //]]></script>
# <![endif]-->
#         <script type="text/javascript">
#          var googletag = googletag || {};
#             googletag.cmd = googletag.cmd || [];
#             googletag.cmd.push(function() {
#
#   googletag.defineSlot('/1000931/dubizzle_desktop/None_LPV_top', [[728,90], [970, 250]], 'dfp-leaderboard-top').addService(googletag.pubads()).setCollapseEmptyDiv(true,true).setTargeting("pos", ["top"]);
#
#   googletag.defineSlot('/1000931/dubizzle_desktop/None_LPV_top', [1,1], 'dfp-onebyone').addService(googletag.pubads()).setCollapseEmptyDiv(true,true);
#
#   googletag.defineSlot('/1000931/dubizzle_desktop/None_LPV_top', [665,35], 'dfp-cpc-top').addService(googletag.pubads()).setCollapseEmptyDiv(true,true).setTargeting("pos", ["top"]);
#
#   googletag.defineSlot('/1000931/dubizzle_desktop/None_LPV_bottom', [665,35], 'dfp-cpc-bottom').addService(googletag.pubads()).setCollapseEmptyDiv(true,true).setTargeting("pos", ["bottom"]);
#
#   googletag.defineSlot('/1000931/dubizzle_desktop/None_LPV_bottom/None', [728,90], 'dfp-leaderboard-bottom').addService(googletag.pubads()).setCollapseEmptyDiv(true,true).setTargeting("pos", ["bottom"]);
#
#
#
#
#
#                 googletag.pubads().enableSingleRequest();
#                 googletag.pubads().disableInitialLoad();
#                 window.DFPTargeting = {};
#
#                 DFPTargeting['site'] = ['ajman'];
#
#                 DFPTargeting['keyword'] = ['ajmanpearl'];
#                 DFPTargeting['language'] = ['en'];
#
#
#
#
#
#
#
#
#
#
#
#         DFPTargeting['page'] = ['1'];
#
#
#
#
#
#         DFPTargeting['full_brand'] = ['False'];
#
#
#        DFPTargeting['CL_Listing'] = ['Search'];
#        DFPTargeting['keyword'] = [''];
#
#
#                 for(var filter in DFPTargeting)
#                     googletag.pubads().setTargeting(filter, DFPTargeting[filter]);
#
#
#
#                 googletag.enableServices();
#             });
#         </script>
#         <script async="" src="https://static.criteo.net/js/ld/publishertag.js" type="text/javascript">
#         </script>
#         <script type="text/javascript">
#          window.Criteo = window.Criteo || {};
#     window.Criteo.events = window.Criteo.events || [];
#     var launchAdServer = function() {
#         googletag.cmd.push(function() {
#             Criteo.SetDFPKeyValueTargeting();
#             googletag.pubads().refresh();
#         });
#     };
#     Criteo.events.push(function() {
#         var adUnit = {
#         "placements": [
#             {
#                 "slotid": "dfp-leaderboard-top",
#                 "zoneid": 898994
#             },
#             {
#                 "slotid": "dfp-leaderboard-bottom",
#                 "zoneid": 898993
#             }
#         ]
#     };
#
#         Criteo.SetLineItemRanges("0..3:0.01;3..8:0.05;8..20:0.50;20..30:1.00");
#         Criteo.RequestBids(adUnit, launchAdServer, 800);
#
#     });
#         </script>
#         <script type="text/javascript">
#          <!--
#
#   (function(W, D, dbz, undefined) {
#       W.dataLayer = W.dataLayer || [];
#       W.dataLayer.push({"resultSetType": "search", "searchString": "ajman pearl", "language": "en", "resultSetFormat": "list", "pageCount": "44", "cityName": "ajman", "trackPage": "resultSet", "cityId": 14, "pageNumber": "1", "resultCount": "438", "platformType": "desktop"});
#
#       var ninjaTag = D.getElementById("ninja-script-tag");
#
#
#       if (!ninjaTag) {
#         "use strict";
#         dbz.defaultConfigTracking = {
#             "siteUrl": "www.dubizzle.com",
#             "environment": "production"
#         };
#
#         W.configTracking = dbz.defaultConfigTracking;
#
#         var script = D.createElement("script");
#         script.type = "text/javascript";
#         script.id = "ninja-script-tag";
#         script.async = true;
#         script.src = ("https:" === D.location.protocol ? "https://" : "http://") + "ninja.onap.io/ninja.js";
#         (D.getElementsByTagName("head")[0] || D.getElementsByTagName("body")[0]).appendChild(script);
#       }
#   }(window, window.document, window.dbz = window.dbz || {}));
#
#
# //-->
#         </script>
#         <link href="/m/search/?keywords=Ajman+Pearl&amp;is_basic_search_widget=1&amp;is_search=1" media="only screen and (max-width: 640px)" rel="alternate"/>
#         <script async="async" src="https://www.google.com/adsense/search/ads.js">
#         </script>
#         <script charset="utf-8" type="text/javascript">
#          (function(g,o){g[o]=g[o]||function(){(g[o]['q']=g[o]['q']||[]).push(
#           arguments)},g[o]['t']=1*new Date})(window,'_googCsa');
#         </script>
#        </link>
#       </link>
#      </link>
#     </link>
#    </meta>
#   </meta>
#  </head>
#  <body class=" country-uae site-ajman classified-listing-p logged-out lang-en " id="classified-listing-body" style="
#
#
#         ">
#   <script type="text/javascript">
#    var dataLayer =  window.dataLayer || [];
#         dataLayer.push({"page_type": "searchresults"});
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   </script>
#   <script type="text/javascript">
#    window.dataLayer = window.dataLayer || [];
#     dataLayer.push({
#         'city': 'ajman',
#         'language': 'en',
#         'loggedin': 'no',
#         'is_lister': 'no'
#     });
#
#     if (location.pathname === "/") {
#         dataLayer.push({'page_type' : 'home'});
#     }
#
#
#         dataLayer.push({'_trackPageview': '/search/keyword/'});
#
#
#     ;(function(p,l,o,w,i,n,g){if(!p[i]){p.GlobalSnowplowNamespace=p.GlobalSnowplowNamespace||[];
#     p.GlobalSnowplowNamespace.push(i);p[i]=function(){(p[i].q=p[i].q||[]).push(arguments)
#     };p[i].q=p[i].q||[];n=l.createElement(o);g=l.getElementsByTagName(o)[0];n.async=1;
#     n.src=w;g.parentNode.insertBefore(n,g)}}(window,document,"script","https://daxfxip0skunh.cloudfront.net/2.4.2/sp.js","snowplow"));
#
#
#     window.snowplow('newTracker', 'cf', 'tracker.dbzstatic.com', { // Initialise a tracker
#       appId: 'dubizzle',
#       cookieDomain: '.dubizzle.com',
#       platform: "False" === "True" ? 'mob':'pc'
#     });
#     window.snowplow('setUserId', 'None');
#
#     if (window.location.hostname.split('.').splice(window.location.hostname.split('.').length-2).join('.') !== "dubizzle.com"){
#
#         var imgId = function guid() {
#             function s4() {
#                 return Math.floor((1 + Math.random()) * 0x10000)
#                     .toString(16)
#                     .substring(1);
#             }
#             return s4() + s4() + '-' + s4() + '-' + s4() + '-' +
#                 s4() + '-' + s4() + s4() + s4();
#         };
#
#         try {
#             var img = document.createElement("img");
#             img.src = "https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/.dist_" + imgId() + "/images/__1x1.png?domain=" + window.location.href;
#             img.style.display = "none";
#             var phContainer = document.getElementsByTagName("body")[0];
#             phContainer.appendChild(img);
#         } catch (e){}
#     }
#
#
#     /**
#      * parseInt4 function
#      * @param integer that need to be parsed and validated
#      * @returns {Integer} validated for Int4 data type limitations
#      */
#     (function (window) {
#
#         window.parseInt4 = function parseInt4(num) {
#             if(parseInt(num) > 2000000000){
#                 return 2000000000;
#             }else if(parseInt(num) < 0){
#                 return 0;
#             }else{
#                 return parseInt(num);
#             }
#         };
#
#     })(this.window = this.window || {});
#   </script>
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-5MTBS9" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-5MTBS9');
#   </script>
#   <!-- <noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-MCM79F"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MCM79F');</script>
#  -->
#   <!--Snowplow js tracker -->
#   <script type="text/javascript">
#    var getSearchParams = function(items){
#                 var keywords = "Ajman Pearl";
#                 var eventContextData = {
#                     listings: items,
#                     isSearch: 0
#                 }
#                 if("None" !== "None") eventContextData['userId'] = None;
#                 if(location.search){
#                     eventContextData["isSearch"] = 1;
#                     var searchInputs = document.getElementById("search-content").querySelectorAll("input, select");
#                     var schemaParamsArr = ["rc", "c1", "c2", "site", "s", "price__gte", "price__lte", "bedrooms__gte","bedrooms__lte", "places__id__in", "keywords"];
#                     [].forEach.call(searchInputs, function(el) {
#                         if(schemaParamsArr.indexOf(el.name) > -1 ){
#                             eventContextData[el.name] = el.value;
#                         }
#                         if(el.name == "places__id__in"){
#                             location.search.split("&").forEach(function(str){
#                                 if(str.split("=")[0] == "places__id__in" && str.split("=")[1]){
#                                     eventContextData["places__id__in"] = decodeURIComponent(str.split("=")[1]).split(",").splice(0, decodeURIComponent(str.split("=")[1]).split(",").length-1);
#                                 }
#                             });
#                         }
#                     });
#                     var propsStr= JSON.stringify(eventContextData);
#                     var eventContextData = JSON.parse(propsStr, function(prop, value) {
#                         switch(prop) {
#                             case "site":
#                                 this.cityId = window.parseInt4(value);
#                                 return;
#                             case "s":
#                                 this.section = value;
#                                 break;
#                             case "price__gte":
#                                 this.priceGTE = window.parseInt4(value);
#                                 break;
#                             case "price__lte":
#                                 this.priceLTE = window.parseInt4(value);
#                                 break;
#                             case "bedrooms__gte":
#                                 this.bedroomsGTE = window.parseInt4(value);
#                                 break;
#                             case "bedrooms__lte":
#                                 this.bedroomsLTE = window.parseInt4(value);
#                                 break;
#                             case "places__id__in":
#                                 this.places = value.join(',').split(',').map(Number);
#                                 break;
#                             default:
#                                 return value;
#                        }
#                     });
#                     eventContextData["rc"] = parseInt(eventContextData["rc"]);
#                     eventContextData["c1"] = parseInt(eventContextData["c1"]);
#                     eventContextData["c2"] = parseInt(eventContextData["c2"]);
#                     for ( key in eventContextData){
#                         if(!eventContextData[key] || eventContextData[key].length == 0){
#                             delete eventContextData[key]
#                         }
#                     }
#                 }
#                 window.snowplow('trackPageView', null, {
#                     schema: "iglu:com.dubizzle/list_page_view/jsonschema/1-0-0",
#                     data: eventContextData
#                 });
#             }
#             var listings = ;
#             var promotedListings = {};
#             if(listings.length > 0)
#                 document.addEventListener('DOMContentLoaded', getSearchParams.bind(this, listings), false);
#             if(promotedListings.length > 0)
#                 document.addEventListener('DOMContentLoaded', getSearchParams.bind(this, promotedListings), false);
#   </script>
#   <!--Snowplow no-js tracker -->
#   <noscript>
#    <img id="sp-nojs-img" src="//tracker.dbzstatic.com/i?&amp;e=pv&amp;url=/search/&amp;aid=dubizzle&amp;p=pc&amp;tv=no-js-0.1.0&amp;userId='None'"/>
#   </noscript>
#   <div id="fb-root" style="overflow:hidden">
#   </div>
#   <div id="gtrans-root" style="overflow:hidden">
#   </div>
#   <div id="page-wrapper">
#    <div id="help-slider" style="display:none">
#    </div>
#    <div id="signin" style="display:none">
#     <div id="signin-content">
#      <div class="group" id="signin-text">
#       <h2>
#        Sign In
#       </h2>
#       <a class="close">
#       </a>
#       <p>
#        <a href="/accounts/register/">
#         or Register
#        </a>
#       </p>
#      </div>
#      <div class="group" id="fbconnect-signin">
#       <div class="facebook-login-top-wrapper">
#        <button class="facebook-login-top" onclick="checkLoginState()">
#         <i class="fa fa-facebook-official">
#         </i>
#         Login with Facebook
#        </button>
#        <p class="facebook-login-top-wrapper__safety-message">
#         We will not post on your Facebook.
#        </p>
#       </div>
#      </div>
#      <img class="sep-img" src="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/images/fbconnect/slideDown_separator.jpg"/>
#      <div class="group" id="signin-form">
#       <form action="/accounts/login/?next=/search/?keywords=Ajman+Pearl&amp;is_basic_search_widget=1&amp;is_search=1" method="post">
#        <div>
#         <label for="email">
#          Email Address:
#         </label>
#         <input id="email" name="username" type="email"/>
#        </div>
#        <div>
#         <label for="password">
#          Password:
#         </label>
#         <input id="password" name="password" type="password"/>
#         <a href="/accounts/password/reset/" id="forgot-password">
#          Forgot Password?
#         </a>
#        </div>
#        <input name="next" type="hidden" value=""/>
#        <input alt="Sign In" id="signin-button" title="Sign In" type="submit" value="Sign In"/>
#       </form>
#      </div>
#     </div>
#    </div>
#    <div id="header">
#     <div class="header-top-bar">
#      <div class="header-top-bar__left">
#       <div id="location-switch">
#        <!--<div class="country" id="country-dropdown">-->
#        <!--<p class="country" id="country-dropdown-trigger">-->
#        <!--<a id="uae" href="/change-location/" onClick="return dbzglobal_event_adapter(this);">-->
#        <!--<span id="country-name-dropdown-trigger">UAE</span>-->
#        <!--</a>-->
#        <!--</p>-->
#        <!--<ul class="country">-->
#        <!-- -->
#        <!--<li>-->
#        <!--<a id="egypt" href="https://olx.com.eg/en/">name</a>-->
#        <!--</li>-->
#        <!-- -->
#        <!--<li>-->
#        <!--<a id="bahrain" href="https://olx.com.bh/en/">name</a>-->
#        <!--</li>-->
#        <!-- -->
#        <!--<li>-->
#        <!--<a id="ksa" href="https://olx.sa.com/en/">KSA</a>-->
#        <!--</li>-->
#        <!-- -->
#        <!--<li>-->
#        <!--<a id="lebanon" href="https://olxliban.com/en/">name</a>-->
#        <!--</li>-->
#        <!-- -->
#        <!--<li>-->
#        <!--<a id="kuwait" href="https://olx.com.kw/en/">name</a>-->
#        <!--</li>-->
#        <!-- -->
#        <!--<li>-->
#        <!--<a id="oman" href="https://olx.com.om/en/">name</a>-->
#        <!--</li>-->
#        <!-- -->
#        <!--<li>-->
#        <!--<a id="qatar" href="https://olx.qa/en/">name</a>-->
#        <!--</li>-->
#        <!-- -->
#        <!--</ul>-->
#        <!--</div>-->
#        <!--<div class="seperator"><p>/</p></div>-->
#        <div class="city" id="city-dropdown">
#         <p class="city" id="city-dropdown-trigger">
#          <a href="/change-location/" onclick="return dbzglobal_event_adapter(this);">
#           <span id="city-name-dropdown-trigger">
#            Ajman
#           </span>
#          </a>
#         </p>
#         <ul class="city">
#          <li id="4">
#           <a href="http://uae.dubizzle.com/change-location/">
#            All Cities (UAE)
#           </a>
#          </li>
#          <li id="city.site.id">
#           <a href="https://abudhabi.dubizzle.com">
#            Abu Dhabi
#           </a>
#          </li>
#          <li id="city.site.id">
#           <a href="https://alain.dubizzle.com">
#            Al Ain
#           </a>
#          </li>
#          <li id="city.site.id">
#           <a href="https://dubai.dubizzle.com">
#            Dubai
#           </a>
#          </li>
#          <li id="city.site.id">
#           <a href="https://fujairah.dubizzle.com">
#            Fujairah
#           </a>
#          </li>
#          <li id="city.site.id">
#           <a href="https://rak.dubizzle.com">
#            Ras al Khaimah
#           </a>
#          </li>
#          <li id="city.site.id">
#           <a href="https://sharjah.dubizzle.com">
#            Sharjah
#           </a>
#          </li>
#          <li id="city.site.id">
#           <a href="https://uaq.dubizzle.com">
#            Umm al Quwain
#           </a>
#          </li>
#         </ul>
#        </div>
#        <script>
#         function city_dropdown_toggle(e){
#                 e.stopPropagation();
#                 $("#city-dropdown").toggleClass("expand");
#                 if($("#account-action-wrapper-dropdown")) {
#                     $("#account-action-wrapper-dropdown").removeClass("opened");
#                 }
#          }
#         $(document).on('click',"#city-dropdown-trigger", city_dropdown_toggle);
#        </script>
#       </div>
#       <div id="parent-user-control">
#        <ul id="user-controls">
#         <li>
#          <a href="/help/" id="user-help">
#           <img src="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/images/nav/help_icon.png"/>
#          </a>
#         </li>
#         <li>
#          <a class="lang-form" href="/ar/search/?keywords=Ajman+Pearl&amp;is_basic_search_widget=1&amp;is_search=1">
#           <span class="language-text">
#            العربية
#           </span>
#          </a>
#         </li>
#         <li class="fbsignin">
#          <a href="#" onclick="checkLoginState(); return false;">
#           <img src="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/images/fbconnect/facebookConnect.png"/>
#          </a>
#         </li>
#         <li class="signin-btn">
#          <a href="/accounts/login/">
#           Sign In
#          </a>
#         </li>
#         <li class="register-btn">
#          <a href="/accounts/register/">
#           Register
#          </a>
#         </li>
#        </ul>
#        <!-- end user-controls -->
#        <!-- for client side ajax rendering -->
#       </div>
#      </div>
#      <div id="logo">
#       <a href="/">
#        <!-- -->
#        <!--<img src="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/images/header/dubizzle_logo_new.png" alt='dubizzle.com' height="40px"/>-->
#        <!-- -->
#       </a>
#      </div>
#      <div class="header-top-bar__right">
#       <script>
#        var LAYER_APP_ID = "layer:///apps/production/0182b1e4-bb97-11e6-92ef-3b6202003503";
#       </script>
#       <span class="hidden" data-text="typing">
#        typing...
#       </span>
#       <span class="hidden" data-text="photo">
#        View Photo
#       </span>
#       <span class="hidden" data-text="location">
#        View Location
#       </span>
#       <span class="hidden" data-text="unsupported">
#        Unsupported Media
#       </span>
#       <span class="hidden" data-text="sending">
#        Sending
#       </span>
#       <span class="hidden" data-text="sent">
#        Sent
#       </span>
#       <span class="hidden" data-text="delivered">
#        Delivered
#       </span>
#       <span class="hidden" data-text="read">
#        Read
#       </span>
#       <span class="hidden" data-text="posted">
#        Posted on:
#       </span>
#       <div id="chat-container">
#        <div data-ati="Top_chat_button_clicked" data-stc='{"lister_num":"None"}' id="chat-icon-status">
#        </div>
#        <div data-ati="Top_chat_button_clicked" data-stc='{"lister_num":"None"}' id="chat-count-badge">
#         <div id="chat-count">
#         </div>
#        </div>
#        <div id="conversations">
#         <div id="conversation-list">
#          <a class="no-chats" href="/chat/">
#           No Chats Available
#          </a>
#         </div>
#         <div id="hub-link">
#          <a href="/chat/">
#           See All Messages
#          </a>
#         </div>
#        </div>
#       </div>
#       <script>
#        $('#chat-container').on('click', function(){
#             window.location.href = "/accounts/login/?next=/chat/";
#         });
#       </script>
#       <div id="callouts">
#        <ul>
#         <li id="place-an-ad">
#          <a class="awesome red" href="/place-an-ad/user/login/" id="place_an_ad_callout_en">
#           Place Your Ad
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div id="nav">
#      <ul class="nav-container">
#       <li class="nav-container-main">
#        <ul class="navbar" id="navbar-id">
#         <li class="parent more" id="nav-motors">
#          <a href="/motors/" title="">
#           <span class="more">
#            Motors
#           </span>
#          </a>
#          <ul class="navbar-inner " id="nav-categories-list-container">
#           <li class="nav-inner-content">
#            <ul class="nav-col-list">
#             <li>
#              <a href="/motors/used-cars/">
#               Used Cars for Sale
#               <strong>
#                (365)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/motors/auto-accessories-parts/">
#               Auto Accessories &amp; Parts
#               <strong>
#                (197)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/motors/boats/">
#               Boats
#               <strong>
#                (55)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/motors/heavy-vehicles/">
#               Heavy Vehicles
#               <strong>
#                (84)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/motors/motorcycles/">
#               Motorcycles
#               <strong>
#                (63)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/motors/number-plates/">
#               Number Plates
#               <strong>
#                (458)
#               </strong>
#              </a>
#             </li>
#            </ul>
#           </li>
#          </ul>
#         </li>
#         <li class="parent more" id="nav-classified">
#          <a href="/classified/" title="">
#           <span class="more">
#            Classifieds
#           </span>
#          </a>
#          <ul class="navbar-inner " id="nav-categories-list-container">
#           <li class="nav-inner-content">
#            <ul class="nav-col-list">
#             <li>
#              <a href="/classified/baby-items/">
#               Baby Items
#               <strong>
#                (584)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/classified/books/">
#               Books
#               <strong>
#                (119)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/classified/business-industrial/">
#               Business &amp; Industrial
#               <strong>
#                (836)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/classified/cameras-imaging/">
#               Cameras &amp; Imaging
#               <strong>
#                (120)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/classified/clothing-accessories/">
#               Clothing &amp; Accessories
#               <strong>
#                (570)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/classified/collectibles/">
#               Collectibles
#               <strong>
#                (63)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/classified/computers-networking/">
#               Computers &amp; Networking
#               <strong>
#                (415)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/classified/dvds-movies/">
#               DVDs &amp; Movies
#               <strong>
#                (3)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/classified/electronics/">
#               Electronics
#               <strong>
#                (381)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/classified/free-stuff/">
#               Free Stuff
#               <strong>
#                (33)
#               </strong>
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="nav-inner-content">
#            <ul class="nav-col-list">
#             <li>
#              <a href="/classified/furniture-home-garden/">
#               Furniture, Home &amp; Garden
#               <strong>
#                (3006)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/classified/gaming/">
#               Gaming
#               <strong>
#                (373)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/classified/home-appliances/">
#               Home Appliances
#               <strong>
#                (801)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/classified/jewelry-watches/">
#               Jewelry &amp; Watches
#               <strong>
#                (151)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/classified/lostfound/">
#               Lost/Found
#               <strong>
#                (4)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/classified/misc/">
#               Misc
#               <strong>
#                (65)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/classified/mobile-phones-pdas/">
#               Mobile Phones &amp; PDAs
#               <strong>
#                (648)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/classified/music/">
#               Music
#               <strong>
#                (6)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/classified/musical-instruments/">
#               Musical Instruments
#               <strong>
#                (73)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/classified/pets/">
#               Pets
#               <strong>
#                (100)
#               </strong>
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="nav-inner-content">
#            <ul class="nav-col-list">
#             <li>
#              <a href="/classified/sports-equipment/">
#               Sports Equipment
#               <strong>
#                (252)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/classified/stuff-wanted/">
#               Stuff Wanted
#               <strong>
#                (9)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/classified/tickets-vouchers/">
#               Tickets &amp; Vouchers
#               <strong>
#                (54)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/classified/toys/">
#               Toys
#               <strong>
#                (94)
#               </strong>
#              </a>
#             </li>
#            </ul>
#           </li>
#          </ul>
#         </li>
#         <li class="parent more" id="nav-property-for-sale">
#          <a href="/property-for-sale/home/" title="">
#           <span class="more">
#            Property for Sale
#           </span>
#          </a>
#          <ul class="navbar-inner " id="nav-categories-list-container">
#           <li class="nav-inner-content">
#            <ul class="nav-col-list">
#             <li>
#              <a href="/en/property-for-sale/residential/apartment/">
#               Apartment for Sale
#               <strong>
#                (909)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/en/property-for-sale/residential/villahouse/">
#               Villa/House for Sale
#               <strong>
#                (1811)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/en/property-for-sale/commercial/">
#               Commercial for Sale
#               <strong>
#                (224)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/en/property-for-sale/multiple-units/">
#               Multiple Units for Sale
#               <strong>
#                (297)
#               </strong>
#              </a>
#             </li>
#             <li>
#              <a href="/en/property-for-sale/land/">
#               Land for Sale
#               <strong>
#                (502)
#               </strong>
#              </a>
#             </li>
#            </ul>
#           </li>
#           <div class="home-loans-link-wrap">
# ...
#                 if(window.topjsLoaded == true){
#                     Modernizr.load([{
#                         load: "//cdn.mediavoice.com/nativeads/script/dubizzle/mediavoice_uae_v2.js"
#                     }]);
#                 }else{
#                     setTimeout(function(){
#                         loadMediavoice();
#                     },200)
#                 }
#         }
#         loadMediavoice();
#   </script>
#   <script>
#    function getSectionIcon(section_code){
#     var iconURL = 'https://afs.googleusercontent.com/dubizzle/';
#     switch (section_code){
#         case 'MT':
#             iconURL += 'motors-icon@2x.png';
#             break;
#         case 'SP':
#             iconURL += 'p-4-s-icon@2x.png';
#             break;
#         case 'RP':
#             iconURL += 'p-4-r-icon@2x.png';
#             break;
#         case 'JB':
#             iconURL += 'jobs-icon@2x.png';
#             break;
#         case 'JW':
#             iconURL += 'jobs-icon@2x.png';
#             break;
#         case 'CO':
#             iconURL += 'community-icon@2x.png';
#             break;
#         default:
#             iconURL += 'items-for-sale-icon@2x.png'
#     }
#     return iconURL;
# }
# (function() {
#     var adIcon = getSectionIcon('');
#     var pageOptions = {
#         "query": "Ajman Pearl Ajman",
#         "pubId": "partner-dubizzle-search",
#         "adPage": "1",
#         "location": false,
#         "hl": "en ",
#         "channel": "search",
#         "number": 4,
#         "sellerRatings": false,
#         "linkTarget": "_blank",
#
#         "adsafe": "medium"
#     };
#
#     var adblock1 = {
#         "container":"adblock1",
#         "width": "740px",
#         'colorTitleLink': '#3b4245',
#         'colorText': '#626465',
#         'colorDomainLink': '#E00000',
#         'colorBackground': '#FFFFFF',
#         'siteLinks': false,
#         'titleBold' : true,
#         "detailedAttribution": false,
#         'fontFamily' : 'roboto, arial, times new roman',
#         'adIconUrl': adIcon,
#         'adIconWidth': 184,
#         'adIconHeight': 120,
#         'adIconSpacingBefore': 0,
#         'adIconSpacingAfter': 16,
#         'domainLinkAboveDescription' : false,
#         'clickableBackgrounds' : true,
#         'noTitleUnderline': true,
#         'fontSizeTitle' : 14,
#         'fontSizeDescription' : 12,
#         'fontSizeDomainLink' : 14,
#         'verticalSpacing' : 24,
#         'lineHeightTitle': 28,
#         'lineHeightDomainLink': 42,
#     };
# _googCsa("ads", pageOptions, adblock1);
# })();
#   </script>
#   <script charset="utf-8" type="text/javascript">
#    //<![CDATA[
#
#             //]]>
#   </script>
#   <script type="text/javascript">
#    var xtnv = document;
#             var xtsd = "https://logs1270";
#             var xtsite = "509193";
#
#             var xtcustom = {"city":"ajman","keyword":"Ajman%20Pearl","nb_results":"438","page_name":"listing_list","filters":"keywords:Ajman%20Pearl/is_basic_search_widget:1","error":"0"};
#             var xt_tags = "[english]";
#             var xtparam_params = "&tag=" + xt_tags;
#             var xtergo = "1";
#             var track_report_item_vars = "";
#
#
#
#             if (window.xtparam != null) {
#                 window.xtparam += xtparam_params;
#             }
#             else {
#                 window.xtparam = xtparam_params;
#             }
#
#
#
#                     var xtidmod = "2";
#
#
#
#
#
#
#             function getURLParameterByName(url, name) {
#                 name = name.replace(/[\[]/, "\\[").replace(/[\]]/, "\\]");
#                 var regex = new RegExp("[\\?&]" + name + "=([^&#]*)"),
#                     results = regex.exec(url);
#                 try {
#                     return decodeURIComponent(results[1].replace(/\+/g, " "));
#                 } catch {
#                     return "";
#                 }
#             }
#
#             var unescapedLocation = decodeURIComponent(window.location.href);
#
#             if (window.optimizely_funnel_page) {
#                 window.xtcustom['funnel_page'] = window.optimizely_funnel_page;
#             } else if(getURLParameterByName(unescapedLocation, "funnel_page")) {
#                 window.xtcustom['funnel_page'] = getURLParameterByName(unescapedLocation, "funnel_page");
#             }
#
#             if (getURLParameterByName(unescapedLocation, "funnel_subsubsection")){
#                 window.xtcustom['funnel_subsubsection'] = getURLParameterByName(unescapedLocation, "funnel_subsubsection");
#             }
#             if (getURLParameterByName(unescapedLocation, "funnel_subsection")){
#                 window.xtcustom['funnel_subsection'] = getURLParameterByName(unescapedLocation, "funnel_subsection");
#             }
#
#             if(window.page_name_override) {
#                 window.xtcustom['page_name'] = window.page_name_override;
#             }
#
#             if (window.optimizely_page_name) {
#                 window.xtcustom['page_name'] = window.optimizely_page_name;
#             }
#
#             if (window.optimizely_funnel_subsection) {
#                 window.xtcustom['funnel_subsection'] = window.optimizely_funnel_subsection;
#             }
#
#             window.ATI_ready = true;
#   </script>
#   <script src="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/js/tracking/xt_clicks.js" type="text/javascript">
#   </script>
#   <script src="https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/js/tracking/xt_core.js?1" type="text/javascript">
#   </script>
#   <noscript>
#    <img alt="" height="1" src="https://logs1270.xiti.com/hit.xiti?s=509193&amp;p=&amp;stc=%7B%22city%22%3A%22ajman%22%2C%22keyword%22%3A%22Ajman%2520Pearl%22%2C%22nb_results%22%3A%22438%22%2C%22page_name%22%3A%22listing_list%22%2C%22filters%22%3A%22keywords%3AAjman%2520Pearl/is_basic_search_widget%3A1%22%2C%22error%22%3A%220%22%7D&amp;ref=&amp;na=497620494" width="1">
#    </img>
#   </noscript>
#   <link href="https://cdn.jsdelivr.net/sweetalert/1.1.3/sweetalert.css" rel="stylesheet"/>
#   <link href="https://cdn.jsdelivr.net/fontawesome/4.5.0/css/font-awesome.min.css" rel="stylesheet"/>
#   <script src="https://cdn.jsdelivr.net/sweetalert/1.1.3/sweetalert.min.js">
#   </script>
#   <script>
#    window.fbAsyncInit = function() {
#     FB.init({
#         appId      : 170382057251,
#         xfbml      : true,
#         version    : 'v2.7'
#     });
# };
#
# (function(d, s, id){
#  var js, fjs = d.getElementsByTagName(s)[0];
#  if (d.getElementById(id)) {return;}
#  js = d.createElement(s); js.id = id;
#  js.src = "//connect.facebook.net/en_US/sdk.js";
#  fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));
#
# function checkLoginState () {
#     FB.login(function(response) {
#         if (response.authResponse) {
#             var outerResponse = response;
#             FB.api('/me/permissions', function(response) {
#                 var declined = [];
#                 for (var i = 0; i < response.data.length; i++) {
#                     if (response.data[i].status == 'declined') {
#                         declined.push(response.data[i].permission)
#                     }
#                 }
#                 if (declined.indexOf('email') !== -1) {
#                     showReaskPrompt();
#                 } else {
#                     sendToken(outerResponse.authResponse.accessToken);
#                 }
#             });
#         } else {
#             console.log('User cancelled login or did not fully authorize.');
#         }
#     }, {scope: 'email,public_profile,user_mobile_phone'});
# }
#
# function showReaskPrompt() {
#     swal({
#         title: "Facebook Login",
#         text: "Your email address could not be retrieved. Try again?",
#         type: "warning",
#         showCancelButton: true,
#         confirmButtonColor: "rgb(89, 162, 92)",
#         confirmButtonText: "Yes",
#         cancelButtonText: "No",
#         closeOnConfirm: true,
#         closeOnCancel: true
#     },
#     function(isConfirm) {
#         if (isConfirm) {
#             reaskEmail()
#         } else {
#             window.location.href = '/accounts/register/'
#         }
#     });
# }
#
# function reaskEmail() {
#     FB.login(
#         function(response) {
#             if (response.authResponse) {
#                 sendToken(response.authResponse.accessToken);
#             }
#         },
#         {
#             scope: 'email',
#             auth_type: 'rerequest'
#         }
#     )
# }
#
# function chooseEmailModal (response) {
#     var response = JSON.parse(response)
#     swal({
#         title: 'Choose which email you want to connect to Facebook',
#         text: '<form id="chosenEmailForm"><label for="chosen_email1">' + response.choices[0] + '</label><input style="display:inline;width:14px;height:14px;" name="chosen_email" id="chosen_email1" type="radio" value="' + response.choices[0] +  '"/><br /><label for="chosen_email2">' + response.choices[1] + '</label><input style="display:inline;width:14px;height:14px;" name="chosen_email" id="chosen_email2" type="radio" value="' + response.choices[1] + '"/></form>',
#         html: true
#     }, function() {
#         var chosenEmail = $("#chosenEmailForm input[type='radio']:checked").val()
#         sendToken(response.token, chosenEmail)
#     })
# }
#
# function getQueryParam(param) {
#     var result =  window.location.search.match(
#         new RegExp("(\\?|&)" + param + "(\\[\\])?=([^&]*)")
#     );
#
#     return result ? result[3] : undefined;
# }
#
# var removeQueryFields = function (url) {
#     var fields = [].slice.call(arguments, 1).join('|'),
#         parts = url.split( new RegExp('[&?](' + fields + ')=[^&]*') ),
#         length = parts.length - 1;
#     return parts[0] + '?' + (length ? parts[length].slice(1) : '');
# }
#
# function getNextUrl() {
#     var url = getQueryParam('next'),
#         other_query_params = removeQueryFields(window.location.search, 'next');
#     if(url) {
#         url = window.location.origin + url;
#     }
#
#     if(url && other_query_params) {
#         url = url + other_query_params;
#     }
#
#     console.log(url);
#     return url;
# }
#
# function sendToken(token, chosenEmail) {
#     var xmlhttp;
#     if (window.XMLHttpRequest) {
#         xmlhttp = new XMLHttpRequest();
#     } else {
#         xmlhttp = new ActiveXObject("Microsoft.XMLHTTP");
#     }
#     xmlhttp.onreadystatechange = function() {
#         if (xmlhttp.readyState == 4 && xmlhttp.status == 200) {
#             sendToAti('login');
#             trackOptimizelyforLogin('facebook_login_register_success')
#             trackOptimizelyforLogin('overall_login_page_success')
#
#             var loginAtiInterval = window.setInterval(function(){
#                 if(DbzGlobal && DbzGlobal.ATI && DbzGlobal.ATI.send_tag) {
#                     window.clearInterval(loginAtiInterval);
#                     var atiObj = window.login_opt_expId ? {funnel_page : window.login_opt_expId} : {};
#                     DbzGlobal.ATI.send_tag('facebook_login_success', atiObj);
#                 }
#             },50);
#
#             var next = getNextUrl();
#             if (next) {
#                 window.location.replace(next);
#             } else {
#                 window.location.reload();
#             }
#         } else if (xmlhttp.readyState == 4 && xmlhttp.status == 201) {
#             sendToAti('signup');
#             trackOptimizelyforLogin('facebook_login_register_success')
#             trackOptimizelyforLogin('overall_login_page_success')
#
#             var loginAtiInterval = window.setInterval(function(){
#                 if(DbzGlobal && DbzGlobal.ATI && DbzGlobal.ATI.send_tag) {
#                     window.clearInterval(loginAtiInterval)
#                     var atiObj = window.login_opt_expId ? {funnel_page : window.login_opt_expId} : {}
#                     DbzGlobal.ATI.send_tag('facebook_login_success', atiObj);
#                 }
#             },50);
#
#             window.location.reload();
#         } else if (xmlhttp.readyState == 4 && xmlhttp.status == 409) {
#             sendToAti('multiEmails');
#             chooseEmailModal(xmlhttp.responseText);
#         } else if (xmlhttp.readyState == 4 && xmlhttp.status == 403) {
#             sendToAti('loginError');
#             window.location.reload()
#         } else if (xmlhttp.readyState == 4 && xmlhttp.status == 406) {
#             sendToAti('loginError');
#             swal("Error", xmlhttp.responseText, "error");
#         } else if (xmlhttp.readyState == 4 && xmlhttp.status == 428) {
#             sendToAti('loginError');
#             swal("Uh oh!", "This Facebook account is already connected with another account", "error")
#         } else if (xmlhttp.readyState == 4) {
#             sendToAti('loginError');
#             console.log('error facebook');
#         }
#     };
#     xmlhttp.open(
#         'GET',
#         '/profile/login/facebook/?access_token=' + token +
#         (chosenEmail ? '&chosen_email=' + encodeURIComponent(chosenEmail) : ''),
#         true
#     );
#     xmlhttp.send();
# }
#
# function trackOptimizelyforLogin(tag) {
#     window['optimizely'] = window['optimizely'] || [];
#     // sends a tracking call to Optimizely for the given event name.
#     window.optimizely.push(["trackEvent", tag]);
# }
#
# function sendToAti(type) {
#     if (typeof xtcustom !== 'undefined') {
#         var tags = xtcustom;
#     } else {
#         var tags = {};
#     }
#     if (type == 'login') {
#         tags.page_name = 'facebook_login'
#         sendCorrectAtiCall(tags)
#     } else if (type == 'signup') {
#         tags.page_name = 'facebook_register'
#         sendCorrectAtiCall(tags)
#     } else if (type == 'multiEmails') {
#         tags.page_name = 'facebook_email_conflict'
#         sendCorrectAtiCall(tags)
#     } else {
#         tags.page_name = 'facebook_error'
#         sendCorrectAtiCall(tags)
#     }
# }
#
# function sendCorrectAtiCall(tags) {
#     try {
#         if (DbzGlobal.ATI.send_hit) {
#             DbzGlobal.ATI.send_hit(encodeURIComponent(JSON.stringify(tags)));
#         } else if (DbzGlobal.ATI.xt_click) {
#             DbzGlobal.ATI.xt_click(encodeURIComponent(JSON.stringify(tags)))
#         } else {
#             // TODO: handle it next time
#         }
#     } catch(e) {
#         console.log(e)
#     }
# }
#   </script>
#   <div id="dfp-onebyone">
#    <script type="text/javascript">
#     googletag.cmd.push(function() { googletag.display('dfp-onebyone'); });
#                 window.onload = function() {
#                     if (window.dataLayer) {
#
#                     }
#                 }
#    </script>
#   </div>
#   <!--[if IE 6]><div id="browser" class="ie6">&nbsp;</div><![endif]-->
#   <!--[if IE 7]><div id="browser" class="ie7">&nbsp;</div><![endif]-->
#   <!--[if IE 8]><div id="browser" class="ie8">&nbsp;</div><![endif]-->
#   <!--[if IE 9]><div id="browser" class="ie9">&nbsp;</div><![endif]-->
#   <script type="text/javascript">
#    (function(){var x = document.createElement('script');x.async = true;
#         x.src = "//creativecdn.com/tags?type=script&id=pr_SEuPXrgLzH6w4llr7WEB_home";
#         document.getElementsByTagName('head')[0].appendChild(x);}());
#   </script>
#   <script>
#    window.addEventListener('load', function() {
#                 if ('serviceWorker' in navigator) {
#                     navigator.serviceWorker.getRegistrations().then(function(registrations) {
#                         registrations.forEach(function(registration) {
#                             registration.unregister()
#                         })
#                     })
#                 }
#             });
#   </script>
#   <script type="application/ld+json">
#    {
#         "@context": "http://schema.org",
#         "@type": "Organization",
#         "name": "dubizzle",
#         "logo": "https://dbzstatic-a.akamaihd.net/.dist_6c0f9297b66a493179380c67d69638d32157fece/images/header/dubizzle_logo_new.png",
#         "description": "dubizzle is your leading free classifieds website in ajman to buy, sell and find anything. Find a properties, cars, jobs, or items for sale in ajman.",
#         "url": "https://ajman.dubizzle.com/",
#         "sameAs": [ "https://www.facebook.com/dubizzle",
#                     "https://twitter.com/dubizzle",
#                     "https://youtube.com/user/Dubizzle",
#                     "https://instagram.com/dubizzle"]
#     }
#   </script>
#  </body>
# </html>

# %%
all=soup.find_all("div",{"class":"cf item"})

# %%
all[0].find("div",{"class":"price"}).text.replace("\n","").replace(" ","")
# Out:
# 'AED25,000'

# %%
for listing in all:
    try:
        for features in listing.find_all("ul",{"class":"features"}):
            for li in features.find_all("li"):
                if "Bedrooms: " in li:
                    print(li.text)
                    print(li.find("strong").text)
                if "Bathrooms: " in li:
                    print(li.text)
                    print(li.find("strong").text)
                if "Price / SqFt: " in li:
                    print(li.text)
                    print(li.find("strong").text)
                if "Size: " in li:
                    print(li.text)
                    print(li.find("strong").text)
        print(" ")
    except:
        print(None)
# Out:
# Bedrooms: 1
# 1
# Bathrooms: 2
# 2
# Size: 1115.00
# 1115.00
#
# Size: 1280.00
# 1280.00
# Bedrooms: 2
# 2
# Bathrooms: 2
# 2
# Price / SqFt: 281 AED
# 281 AED
#
# Size: 1813.00
# 1813.00
# Bedrooms: 2
# 2
# Bathrooms: 3
# 3
# Price / SqFt: 193 AED
# 193 AED
#
# Bedrooms: 2
# 2
# Bathrooms: 2
# 2
# Size: 1566.00
# 1566.00
#
# Bedrooms: 2
# 2
# Bathrooms: 3
# 3
# Size: 1600.00
# 1600.00
#
# Bedrooms: 1
# 1
# Bathrooms: 2
# 2
# Size: 1150.00
# 1150.00
#
# Bedrooms: 1
# 1
# Bathrooms: 2
# 2
# Size: 1004.00
# 1004.00
#
# Bedrooms: 2
# 2
# Bathrooms: 2
# 2
# Size: 1280.00
# 1280.00
#
# Bedrooms: 2
# 2
# Bathrooms: 2
# 2
# Size: 1300.00
# 1300.00
#
# Bedrooms: 2
# 2
# Bathrooms: 2
# 2
# Size: 1248.00
# 1248.00

# %%
for listing in all:
    print(listing.find("span",{"class":"title"}).text)
    print(listing.find("div",{"class":"price"}).text.replace("\n","").replace(" ",""))
    try:
        print(listing.find_all("ul",{"class":"features"})[0].find_all("li"))
    except:
        print(None)
    try:
        print(listing.find_all("ul",{"class":"features"})[0].find_all("li")[0].find("strong").text)
    except:
        print(None)
    try:
        print(listing.find_all("ul",{"class":"features"})[0].find_all("li")[1].find("strong").text)
    except:
        print(None)  
    try:
        print(listing.find_all("ul",{"class":"features"})[1].find_all("li"))  
    except:
        print(None)
    try:
        print(listing.find_all("ul",{"class":"features"})[1].find_all("li")[0].find("strong").text)
    except:
        print(None)
    try:
        print(listing.find_all("ul",{"class":"features"})[1].find_all("li")[1].find("strong").text)
    except:
        print(None)
# Out:
#
#                                      1bhk 25000 AED in rashdiya tower { 2bhk 31000...
#
#
#
# AED25,000
# [<li>Bedrooms: <strong>1</strong></li>, <li>Bathrooms: <strong>2</strong></li>]
# 1
# 2
# [<li>Size: <strong>1115.00</strong></li>]
# 1115.00
# None
#
#
#
#                                      GRAB THE BEST DEAL!!! CITY VIEW 2 BEDROOM FOR...
#
#
#
# AED360,000
# [<li>Size: <strong>1280.00</strong></li>, <li>Bedrooms: <strong>2</strong></li>]
# 1280.00
# 2
# [<li>Bathrooms: <strong>2</strong></li>, <li>Price / SqFt: <strong>281 AED</strong></li>]
# 2
# 281 AED
#
#
#
#                                      Naimiyah Towers: EMPTY, 2 Bed Hall + Maid 181...
#
#
#
# AED350,000
# [<li>Size: <strong>1813.00</strong></li>, <li>Bedrooms: <strong>2</strong></li>]
# 1813.00
# 2
# [<li>Bathrooms: <strong>3</strong></li>, <li>Price / SqFt: <strong>193 AED</strong></li>]
# 3
# 193 AED
#
#
#
#                                      Rashidiya Towers: 2 Bed Hall (OPEN VIEW) 1566...
#
#
#
# AED30,000
# [<li>Bedrooms: <strong>2</strong></li>, <li>Bathrooms: <strong>2</strong></li>]
# 2
# 2
# [<li>Size: <strong>1566.00</strong></li>]
# 1566.00
# None
#
#
#
#                                      Ajman ONE Towers: 2 BHK (Close Kitchen) and P...
#
#
#
# AED38,000
# [<li>Bedrooms: <strong>2</strong></li>, <li>Bathrooms: <strong>3</strong></li>]
# 2
# 3
# [<li>Size: <strong>1600.00</strong></li>]
# 1600.00
# None
#
#
#
#                                      Ajman ONE Towers: 1 Bed Hall (2 Washroom) and...
#
#
#
# AED30,000
# [<li>Bedrooms: <strong>1</strong></li>, <li>Bathrooms: <strong>2</strong></li>]
# 1
# 2
# [<li>Size: <strong>1150.00</strong></li>]
# 1150.00
# None
#
#
#
#                                      Falcon Towers: 1 Bed Hall and Parking (2 Wash...
#
#
#
# AED25,000
# [<li>Bedrooms: <strong>1</strong></li>, <li>Bathrooms: <strong>2</strong></li>]
# 1
# 2
# [<li>Size: <strong>1004.00</strong></li>]
# 1004.00
# None
#
#
#
#                                      Ajman Pearl Towers: Sea view, 2 BHK with Park...
#
#
#
# AED33,000
# [<li>Bedrooms: <strong>2</strong></li>, <li>Bathrooms: <strong>2</strong></li>]
# 2
# 2
# [<li>Size: <strong>1280.00</strong></li>]
# 1280.00
# None
#
#
#
#                                      2 Bhk Apartment(Creek View)(With Parking)-Pea...
#
#
#
# AED33,000
# [<li>Bedrooms: <strong>2</strong></li>, <li>Bathrooms: <strong>2</strong></li>]
# 2
# 2
# [<li>Size: <strong>1300.00</strong></li>]
# 1300.00
# None
#
#
#
#                                      2 BHk Apartment(Open View)(Close Kitchen)-Cit...
#
#
#
# AED35,000
# [<li>Bedrooms: <strong>2</strong></li>, <li>Bathrooms: <strong>2</strong></li>]
# 2
# 2
# [<li>Size: <strong>1248.00</strong></li>]
# 1248.00
# None

# %%
pages=soup.find_all("span",{"class":"paginator-simple"})[0].find_all("strong")[1].text
pages
# Out:
# '44'

# %%
url_part1="https://ajman.dubizzle.com/search/?page="
url_part2="&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1"

for page in range(1,int(pages)+1):
    print(url_part1+str(page)+url_part2)
# Out:
# https://ajman.dubizzle.com/search/?page=1&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=2&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=3&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=4&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=5&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=6&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=7&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=8&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=9&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=10&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=11&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=12&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=13&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=14&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=15&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=16&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=17&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=18&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=19&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=20&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=21&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=22&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=23&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=24&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=25&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=26&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=27&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=28&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=29&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=30&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=31&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=32&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=33&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=34&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=35&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=36&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=37&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=38&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=39&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=40&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=41&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=42&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=43&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=44&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1

# %%
for listing in all:
    print(listing.find("span",{"class":"title"}).text)
    print(listing.find("div",{"class":"price"}).text.replace("\n","").replace(" ",""))
    try:
        for features in listing.find_all("ul",{"class":"features"}):
            for li in features.find_all("li"):
                if "Bedrooms: " in li:
                    print(li.text)
                    print(li.find("strong").text)
                if "Bathrooms: " in li:
                    print(li.text)
                    print(li.find("strong").text)
                if "Price / SqFt: " in li:
                    print(li.text)
                    print(li.find("strong").text)
                if "Size: " in li:
                    print(li.text)
                    print(li.find("strong").text)
        print(" ")
    except:
        print(None)
# Out:
#
#                                      1bhk 25000 AED in rashdiya tower { 2bhk 31000...
#
#
#
# AED25,000
# Bedrooms: 1
# 1
# Bathrooms: 2
# 2
# Size: 1115.00
# 1115.00
#
#
#
#
#                                      GRAB THE BEST DEAL!!! CITY VIEW 2 BEDROOM FOR...
#
#
#
# AED360,000
# Size: 1280.00
# 1280.00
# Bedrooms: 2
# 2
# Bathrooms: 2
# 2
# Price / SqFt: 281 AED
# 281 AED
#
#
#
#
#                                      Naimiyah Towers: EMPTY, 2 Bed Hall + Maid 181...
#
#
#
# AED350,000
# Size: 1813.00
# 1813.00
# Bedrooms: 2
# 2
# Bathrooms: 3
# 3
# Price / SqFt: 193 AED
# 193 AED
#
#
#
#
#                                      Rashidiya Towers: 2 Bed Hall (OPEN VIEW) 1566...
#
#
#
# AED30,000
# Bedrooms: 2
# 2
# Bathrooms: 2
# 2
# Size: 1566.00
# 1566.00
#
#
#
#
#                                      Ajman ONE Towers: 2 BHK (Close Kitchen) and P...
#
#
#
# AED38,000
# Bedrooms: 2
# 2
# Bathrooms: 3
# 3
# Size: 1600.00
# 1600.00
#
#
#
#
#                                      Ajman ONE Towers: 1 Bed Hall (2 Washroom) and...
#
#
#
# AED30,000
# Bedrooms: 1
# 1
# Bathrooms: 2
# 2
# Size: 1150.00
# 1150.00
#
#
#
#
#                                      Falcon Towers: 1 Bed Hall and Parking (2 Wash...
#
#
#
# AED25,000
# Bedrooms: 1
# 1
# Bathrooms: 2
# 2
# Size: 1004.00
# 1004.00
#
#
#
#
#                                      Ajman Pearl Towers: Sea view, 2 BHK with Park...
#
#
#
# AED33,000
# Bedrooms: 2
# 2
# Bathrooms: 2
# 2
# Size: 1280.00
# 1280.00
#
#
#
#
#                                      2 Bhk Apartment(Creek View)(With Parking)-Pea...
#
#
#
# AED33,000
# Bedrooms: 2
# 2
# Bathrooms: 2
# 2
# Size: 1300.00
# 1300.00
#
#
#
#
#                                      2 BHk Apartment(Open View)(Close Kitchen)-Cit...
#
#
#
# AED35,000
# Bedrooms: 2
# 2
# Bathrooms: 2
# 2
# Size: 1248.00
# 1248.00

# %%
import pandas
import requests
from bs4 import BeautifulSoup


l=[]
r=requests.get('https://ajman.dubizzle.com/search/?keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1')
c=r.content
soup=BeautifulSoup(c,"html.parser")
pages=soup.find_all("span",{"class":"paginator-simple"})[0].find_all("strong")[1].text
url_part1="https://ajman.dubizzle.com/search/?page="
url_part2="&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1"

for page in range(1,int(pages)+1):
    print(url_part1+str(page)+url_part2)
    r=requests.get(url_part1+str(page)+url_part2)
    c=r.content
    soup=BeautifulSoup(c,"html.parser")
    
    all=soup.find_all("div",{"class":"cf item"})
    for listing in all:
        d={}
        d["title"]=listing.find("span",{"class":"title"}).text.replace("\n","")
        d["price"]=listing.find("div",{"class":"price"}).text.replace("\n","").replace(" ","")
        try:
            for features in listing.find_all("ul",{"class":"features"}):
                for li in features.find_all("li"):
                    if "Bedrooms: " in li:
                        #print(li.text)
                        d["Bedrooms"]=li.find("strong").text
                    if "Bathrooms: " in li:
                        #print(li.text)
                        d["Bathrooms"]=li.find("strong").text
                    if "Price / SqFt: " in li:
                        #print(li.text)
                        d["Price/Sqft"]=li.find("strong").text
                    if "Size: " in li:
                        #print(li.text)
                        d["Size"]=li.find("strong").text

            #print(" ")
        except:
            None
        l.append(d)

df=pandas.DataFrame(l)
df.to_csv("extract.csv")
# Out:
# https://ajman.dubizzle.com/search/?page=1&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=2&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=3&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=4&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=5&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=6&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=7&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=8&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=9&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=10&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=11&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=12&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=13&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=14&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=15&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=16&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=17&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=18&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=19&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=20&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=21&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=22&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=23&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=24&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=25&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=26&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=27&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=28&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=29&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=30&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=31&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=32&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=33&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=34&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=35&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=36&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=37&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=38&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=39&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=40&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=41&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=42&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=43&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=44&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
# https://ajman.dubizzle.com/search/?page=45&keywords=Ajman+Pearl&is_basic_search_widget=1&is_search=1
